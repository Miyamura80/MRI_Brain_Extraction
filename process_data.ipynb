# %%
import torch
import matplotlib.pyplot as plt
import numpy as np

# %%
import nibabel as nib    #Package for loading nii images 
import torchio as tio

brain = np.load('./brain_extraction/brain_extraction/brain_extraction_part1/X_Guys.npy')

# brain = nib.load('./brain_extraction/brain_extraction/brain_extraction_part1/X_Guys.npy').get_fdata()
print(brain.shape)

plt.subplot(1,3,1)
plt.imshow(np.rot90(brain[:,:,:,91]), cmap='gray')
plt.axis('off')
plt.subplot(1,3,2)
plt.imshow(np.rot90(brain[:,:,107,:]), cmap='gray')
plt.axis('off')
plt.subplot(1,3,3)
plt.imshow(np.rot90(brain[:,91,:,:]), cmap='gray')
plt.axis('off')

brain = np.reshape(brain, (1, 182, 218, 182)) #Need 4D for the torchio transforms
brain = torch.from_numpy(brain)
# Out:
# (317, 40, 128, 128)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /home/eitomiyamura/Github/MRI_Brain_Extraction/process_data.ipynb Cell 2 in 1
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/eitomiyamura/Github/MRI_Brain_Extraction/process_data.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=6'>7</a> print(brain.shape)
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/eitomiyamura/Github/MRI_Brain_Extraction/process_data.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=8'>9</a> plt.subplot(1,3,1)
# ---> <a href='vscode-notebook-cell://wsl%2Bubuntu/home/eitomiyamura/Github/MRI_Brain_Extraction/process_data.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=9'>10</a> plt.imshow(np.rot90(brain[:,:,91]), cmap='gray')
# ...
